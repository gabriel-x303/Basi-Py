# %% [markdown]
# # Preparando e manipulando bases de dados

# %%
import pandas as pd

# %%
df = pd.read_csv("USA_Housing.csv")

# %% [markdown]
# ### Conhecendo a estrutura

# %%
df.head(10)
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
# 5      80175.754159             4.988408                   6.104512
# 6      64698.463428             6.025336                   8.147760
# 7      78394.339278             6.989780                   6.620478
# 8      59927.660813             5.362126                   6.393121
# 9      81885.927184             4.423672                   8.167688
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# ...

# %% [markdown]
# ### Corrigindo o problema na base

# %%
df.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
test = pd.read_csv("teste.csv", sep = ";")
test
# Out:
#      Nome Valor
# 0    Maçã   1,5
# 1    Pera   1,3
# 2     Uva     2
# 3  Goiaba   0,9

# %%
test["Valor"]
# Out:
# 0    1,5
# 1    1,3
# 2      2
# 3    0,9
# Name: Valor, dtype: object

# %%
test["Valor"] = test["Valor"].str.replace(",", ".")
test
# Out:
#      Nome Valor
# 0    Maçã   1.5
# 1    Pera   1.3
# 2     Uva     2
# 3  Goiaba   0.9

# %%
test["Valor"] = pd.to_numeric(test["Valor"])

# %%
test.info()
test
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Nome    4 non-null      object
#  1   Valor   4 non-null      float64
# dtypes: float64(1), object(1)
# memory usage: 196.0+ bytes
#      Nome  Valor
# 0    Maçã    1.5
# 1    Pera    1.3
# 2     Uva    2.0
# 3  Goiaba    0.9

# %% [markdown]
# ### Consultas simples

# %%
df.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
df.tail()
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# 4995                          3.46     22837.361035  1.060194e+06
# 4996                          4.02     25616.115489  1.482618e+06
# 4997                          2.13     33266.145490  1.030730e+06
# 4998                          5.44     42625.620156  1.198657e+06
# 4999                          4.07     46501.283803  1.298950e+06
#
#                                                 Address
# 4995                   USNS Williams\nFPO AP 30153-7653
# ...

# %%
df.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %%
df["Price"].describe()
# Out:
# count    5.000000e+03
# mean     1.232073e+06
# std      3.531176e+05
# min      1.593866e+04
# 25%      9.975771e+05
# 50%      1.232669e+06
# 75%      1.471210e+06
# max      2.469066e+06
# Name: Price, dtype: float64

# %%
df[["Address", "Avg. Area Income", "Price"]]
# Out:
#                                                 Address  Avg. Area Income  \
# 0     208 Michael Ferry Apt. 674\nLaurabury, NE 3701...      79545.458574
# 1     188 Johnson Views Suite 079\nLake Kathleen, CA...      79248.642455
# 2     9127 Elizabeth Stravenue\nDanieltown, WI 06482...      61287.067179
# 3                             USS Barnett\nFPO AP 44820      63345.240046
# 4                            USNS Raymond\nFPO AE 09386      59982.197226
# ...                                                 ...               ...
# 4995                   USNS Williams\nFPO AP 30153-7653      60567.944140
# 4996              PSC 9258, Box 8489\nAPO AA 42991-3352      78491.275435
# 4997  4215 Tracy Garden Suite 076\nJoshualand, VA 01...      63390.686886
# 4998                          USS Wallace\nFPO AE 73316      68001.331235
# 4999  37778 George Ridges Apt. 509\nEast Holly, NV 2...      65510.581804
#
#              Price
# 0     1.059034e+06
# 1     1.505891e+06
# ...

# %% [markdown]
# ### Análises aprofundadas

# %%
df["Price"].sum()
# Out:
# 6160363270.711784

# %%
df.groupby("Avg. Area Number of Bedrooms").sum().head(10)
# Out:
#                               Avg. Area Income  Avg. Area House Age  \
# Avg. Area Number of Bedrooms
# 2.00                              1.369179e+06           129.780336
# 2.01                              1.123797e+06            90.123837
# 2.02                              1.371509e+06           116.033279
# 2.03                              9.367065e+05            78.021221
# 2.04                              1.645135e+06           154.519630
# 2.05                              1.183076e+06           110.897687
# 2.06                              7.943757e+05            74.903424
# 2.07                              1.079622e+06            95.877536
# 2.08                              6.321881e+05            49.256529
# 2.09                              1.285671e+06           109.415048
#
#                               Avg. Area Number of Rooms  Area Population  \
# Avg. Area Number of Bedrooms
# 2.00                                         125.603237    763693.850577
# ...

# %%
df.groupby("Avg. Area Number of Bedrooms")["Price"].sum()
# Out:
# Avg. Area Number of Bedrooms
# 2.00    2.438600e+07
# 2.01    1.710362e+07
# 2.02    2.216969e+07
# 2.03    1.356479e+07
# 2.04    2.858745e+07
#             ...
# 6.46    1.389265e+07
# 6.47    9.109196e+06
# 6.48    1.073726e+07
# 6.49    1.890221e+07
# 6.50    1.865789e+07
# Name: Price, Length: 255, dtype: float64

# %%
ex = pd.read_excel("Exemple.xlsx")
ex.head(10)
# Out:
#    COD MOVIMENTO  COD PRODUTO                   DESCRIÇÃO PRODUTO   CATEGORIA  \
# 0              1            6  BERMUDA FITNESS FEMININA ESTAMPADA      Roupas
# 1              2            4      BERMUDA FITNESS FEMININA CINZA      Roupas
# 2              3            2    AGASALHO FEMININO ACADEMIA PRETO      Roupas
# 3              4           28               LUVA MUSCULAÇÃO PRETA  Acessórios
# 4              5           26              MEIA DE CORRIDA BRANCA    Calçados
# 5              6            5       BERMUDA FITNESS FEMININA ROSA      Roupas
# 6              7            9                 CALÇA FEMININA ROSA      Roupas
# 7              8           21                REGATA FEMININA ROSA      Roupas
# 8              9           27               MEIA DE CORRIDA PRETA    Calçados
# 9             10           20               REGATA FEMININA PRETA      Roupas
#
#   SUBCATEGORIA  CUSTO UNITÁRIO  PREÇO UNITÁRIO  RECEITA TOTAL  CUSTO TOTAL  \
# ...

# %%
# Receita por categoria
ex.groupby("CATEGORIA")["RECEITA TOTAL"].sum()
# Out:
# CATEGORIA
# Acessórios     29450.80
# Calçados      103815.43
# Roupas        299960.06
# Name: RECEITA TOTAL, dtype: float64

# %%
# Receita por categoria e subcategoria
ex.groupby(["CATEGORIA", "SUBCATEGORIA"])["RECEITA TOTAL"].sum(numeric_only = True)
# Out:
# CATEGORIA   SUBCATEGORIA
# Acessórios  Bolsas           20287.63
#             Luvas             9163.17
# Calçados    Meias            14381.02
#             Tênis Corrida    89434.41
# Roupas      Agasalhos         7678.94
#             Bermudas         68303.40
#             Calças           66845.09
#             Camisetas        74801.38
#             Jaquetas         21048.87
#             Regatas          61282.38
# Name: RECEITA TOTAL, dtype: float64

# %%
ex[ex["CATEGORIA"] == "Calçados"].groupby("CATEGORIA").sum(numeric_only = True)
# Out:
#            COD MOVIMENTO  COD PRODUTO  CUSTO UNITÁRIO  PREÇO UNITÁRIO  \
# CATEGORIA
# Calçados          393408        10169        15575.37        46420.87
#
#            RECEITA TOTAL  CUSTO TOTAL  VENDAS
# CATEGORIA
# Calçados       103815.43     34965.93     957

# %% [markdown]
# ### Gráficos

# %%
# !pip install plotly_express

# %%
import plotly_express as px

# %%
px.histogram(ex, x = "CATEGORIA", y = "RECEITA TOTAL", text_auto = True, color = "CATEGORIA")

# %%
px.histogram(ex, x = "CATEGORIA", y = "RECEITA TOTAL", text_auto = True, color = "SUBCATEGORIA")

# %%
gec = px.histogram(ex, x = ["CATEGORIA", "ID LOJA"], y = "VENDAS", text_auto = True)

# %%
gec.write_html("Gráfico.html")
